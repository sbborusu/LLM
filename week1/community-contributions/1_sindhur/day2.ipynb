# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import requests

# %%
#Get google api key and validate
load_dotenv(override=True)
google_api_key = os.getenv("GOOGLE_API_KEY")
if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
gemini = OpenAI(base_url='https://generativelanguage.googleapis.com/v1beta/openai/', api_key=google_api_key)
response = gemini.chat.completions.create(model='gemini-2.5-flash', messages=[{"role": "user", "content":"Tell me a fun fact"}])
response.choices[0].message.content
# Out:
# "Here's a fun one:\n\n**Honey never spoils!** Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible. It's due to its low water content and high acidity, which makes it an inhospitable environment for bacteria and microorganisms."

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# 'ollama' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !ollama pull llama3.2
# Out:
# 'ollama' is not recognized as an internal or external command,
# operable program or batch file.

# %%
OLLAMA_BASE_URL = 'http://localhost:11434/v1'
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama') #api_key can be passed anything here

# %%
response = ollama.chat.completions.create(model='llama3.2', messages=[{"role": "user", "content":"Tell me a fun fact"}])
response.choices[0].message.content
# Out:
# 'Here\'s one:\n\nDid you know that there is a species of jellyfish that is immortal?! The Turritopsis dohrnii, also known as the "immortal jellyfish," is a type of jellyfish that can transform its body into a younger state through a process called transdifferentiation. This means that it can essentially revert back to its polyp stage and start its life cycle all over again, making it theoretically immortal!\n\nIsn\'t that cool (and a little creepy)?'

# %%
response = ollama.chat.completions.create(model='deepseek-r1:1.5b', messages=[{"role": "user", "content":"Tell me a fun fact"}])
response.choices[0].message.content
# Out:
# 'Here’s a fun fact for you: **Squash is the only fruit that can be used to make both sweet and savory quich!**'

# %% [markdown]
# # Home Assignment
